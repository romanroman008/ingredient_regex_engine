# %%
from regex_engine import ResolvedIngredient
from regex_engine.application.dto.agent.parsed_ingredient import ParsedIngredient
from regex_engine.ports.regex_registry import RegexRegistryReader

string_data = """
2 jajka kurki zielononóżki
5 dużych łyżek twarogu wiejskiego
2 szklanki mleka
szczypta kurkumy
500 g makaronu pełnoziarnistego
200 mililitrów wody
sos rybny (lub sos sojowy)
"""

mapping: dict[str, ParsedIngredient] = {
    "2 jajka kurki zielononóżki": ParsedIngredient(
        raw_input="2 jajka kurki zielononóżki",
        amount=2,
        unit_size="",
        unit="",
        condition="",
        name="jajka kurki zielononóżki",
        extra="",
    ),
    "5 dużych łyżek twarogu wiejskiego": ParsedIngredient(
        raw_input="5 dużych łyżek twarogu wiejskiego",
        amount=5,
        unit_size="dużych",
        unit="łyżek",
        condition="",
        name="twarogu wiejskiego",
        extra="",
    ),
    "2 szklanki mleka": ParsedIngredient(
        raw_input="2 szklanki mleka",
        amount=2,
        unit_size="",
        unit="szklanki",
        condition="",
        name="mleka",
        extra="",
    ),
    "szczypta kurkumy": ParsedIngredient(
        raw_input="szczypta kurkumy",
        amount=1,
        unit_size="",
        unit="szczypta",
        condition="",
        name="kurkumy",
        extra="",
    ),
    "500 g makaronu pełnoziarnistego": ParsedIngredient(
        raw_input="500 g makaronu pełnoziarnistego",
        amount=500,
        unit_size="",
        unit="g",
        condition="",
        name="makaronu pełnoziarnistego",
        extra="",
    ),
    "200 mililitrów wody": ParsedIngredient(
        raw_input="200 mililitrów wody",
        amount=200,
        unit_size="",
        unit="mililitrów",
        condition="",
        name="wody",
        extra="",
    ),
    "sos rybny (lub sos sojowy)": ParsedIngredient(
        raw_input="sos rybny (lub sos sojowy)",
        amount=1,
        unit_size="",
        unit="",
        condition="",
        name="sos rybny",
        extra="lub sos sojowy",
    ),
}

# %%
def print_registry(registry: RegexRegistryReader):
    print(f"Registry: {registry.kind.name}")
    for entry in registry.get_all():
        print(f"stem : {entry.stem}")
        print(f"variants: {entry.variants}")
        print(f"regex: {entry.pattern.pattern}")
        print("---------------------------------")

# %%
def print_resolved_ingredients(ingredients: list[ResolvedIngredient]):
    for ingredient in ingredients:
        print(f"ingredient: {ingredient.name}")
        print(ingredient)

# %%
from regex_engine.api import create_demo

regex_engine = create_demo(mapping)

await regex_engine.learn(string_data)

# %%
recognized = regex_engine.recognize_ingredients(string_data)


recognized
# Out:
# [ResolvedIngredient(raw_input='2 jajka kurki zielononóżki', amount=2.0, unit_size=None, unit=None, condition=None, name='jajko_kurka_zielononóżki', extra=''),
#  ResolvedIngredient(raw_input='5 dużych łyżek twarogu wiejskiego', amount=5.0, unit_size='duży', unit='łyżka', condition=None, name='twaróg_wiejski', extra=''),
#  ResolvedIngredient(raw_input='2 szklanki mleka', amount=2.0, unit_size=None, unit='szklanka', condition=None, name='mleko', extra=''),
#  ResolvedIngredient(raw_input='szczypta kurkumy', amount=1, unit_size=None, unit='szczypta', condition=None, name='kurkuma', extra=''),
#  ResolvedIngredient(raw_input='500 g makaronu pełnoziarnistego', amount=500.0, unit_size=None, unit='gram', condition=None, name='makaron_pełnoziarnisty', extra=''),
#  ResolvedIngredient(raw_input='200 mililitrów wody', amount=200.0, unit_size=None, unit='mililitr', condition=None, name='woda', extra=''),
#  ResolvedIngredient(raw_input='sos rybny (lub sos sojowy)', amount=1, unit_size=None, unit=None, condition=None, name='sos_rybny', extra='lub sos sojowy')]

# %%
regex_container = regex_engine.get_registries()

# %%
print_registry(regex_container.ingredient_registry)
# Out:
# Registry: INGREDIENT_NAME
# stem : jajko_kurka_zielononóżki
# variants: frozenset({'jajkiem kurki zielononóżki', 'jajkiem kurką zielononóżki', 'jajka kurek zielononóżki', 'jajkami kurek zielononóżki', 'jajka kurki zielononóżki', 'jajko kurka zielononóżki', 'jajkami kurkami zielononóżki', 'jajko kurki zielononóżki', 'jajko kurkę zielononóżki', 'jajek kurek zielononóżki'})
# regex: \b(?:jajkami\ kurkami\ zielononóżki|jajkami\ kurek\ zielononóżki|jajkiem\ kurki\ zielononóżki|jajkiem\ kurką\ zielononóżki|jajek\ kurek\ zielononóżki|jajka\ kurek\ zielononóżki|jajka\ kurki\ zielononóżki|jajko\ kurka\ zielononóżki|jajko\ kurki\ zielononóżki|jajko\ kurkę\ zielononóżki)\b
# ---------------------------------
# stem : kurkuma
# variants: frozenset({'kurkumami', 'kurkum', 'kurkumę', 'kurkumą', 'kurkumy', 'kurkuma'})
# regex: \b(?:kurkumami|kurkuma|kurkumy|kurkumą|kurkumę|kurkum)\b
# ---------------------------------
# stem : makaron_pełnoziarnisty
# variants: frozenset({'makaronami pełnoziarnistymi', 'makarony pełnoziarniste', 'makaronów pełnoziarnistych', 'makaron pełnoziarnisty', 'makaronu pełnoziarnistego', 'makaronem pełnoziarnistym'})
# regex: \b(?:makaronami\ pełnoziarnistymi|makaronów\ pełnoziarnistych|makaronem\ pełnoziarnistym|makaronu\ pełnoziarnistego|makarony\ pełnoziarniste|makaron\ pełnoziarnisty)\b
# ---------------------------------
# stem : mleko
# variants: frozenset({'mlekiem', 'mlekami', 'mlek', 'mleko', 'mleka'})
# regex: \b(?:mlekami|mlekiem|mleka|mleko|mlek)\b
# ---------------------------------
# stem : sos_rybny
# variants: frozenset({'sosem rybnym', 'sosu rybnego', 'sosów rybnych', 'sos rybny', 'sosy rybne', 'sosami rybnymi'})
# regex: \b(?:sosami\ rybnymi|sosów\ rybnych|sosem\ rybnym|sosu\ rybnego|sosy\ rybne|sos\ rybny)\b
# ---------------------------------
# stem : twaróg_wiejski
# variants: frozenset({'twarogi wiejskie', 'twarogów wiejskich', 'twarogami wiejskimi', 'twarogu wiejskiego', 'twarogiem wiejskim', 'twaróg wiejski'})
# regex: \b(?:twarogami\ wiejskimi|twarogiem\ wiejskim|twarogu\ wiejskiego|twarogów\ wiejskich|twarogi\ wiejskie|twaróg\ wiejski)\b
# ---------------------------------
# stem : woda
# variants: frozenset({'wodą', 'wodę', 'wodami', 'wód', 'woda', 'wody'})
# regex: \b(?:wodami|woda|wody|wodą|wodę|wód)\b
# ---------------------------------

# %%
print_registry(regex_container.unit_registry)
# Out:
# Registry: UNIT
# stem : gram
# variants: frozenset({'gram', 'gramem', 'gramami', 'grama', 'gramy', 'g'})
# regex: \b(?:gramami|gramem|grama|gramy|gram|g)\b
# ---------------------------------
# stem : mililitr
# variants: frozenset({'mililitra', 'mililitrem', 'mililitrów', 'mililitr', 'mililitrami', 'mililitry'})
# regex: \b(?:mililitrami|mililitrem|mililitrów|mililitra|mililitry|mililitr)\b
# ---------------------------------
# stem : szczypta
# variants: frozenset({'szczyptą', 'szczypt', 'szczypta', 'szczyptę', 'szczypty', 'szczyptami'})
# regex: \b(?:szczyptami|szczypta|szczypty|szczyptą|szczyptę|szczypt)\b
# ---------------------------------
# stem : szklanka
# variants: frozenset({'szklankami', 'szklanek', 'szklanka', 'szklanki', 'szklanką', 'szklankę'})
# regex: \b(?:szklankami|szklanek|szklanka|szklanki|szklanką|szklankę)\b
# ---------------------------------
# stem : łyżka
# variants: frozenset({'łyżek', 'łyżkami', 'łyżki', 'łyżka', 'łyżkę', 'łyżką'})
# regex: \b(?:łyżkami|łyżek|łyżka|łyżki|łyżką|łyżkę)\b
# ---------------------------------

# %%
print_registry(regex_container.unit_size_registry)
# Out:
# Registry: UNIT_SIZE
# stem : duży
# variants: frozenset({'duże', 'dużych', 'duży', 'duża', 'dużego', 'dużą', 'dużym', 'dużymi', 'dużej'})
# regex: \b(?:dużego|dużych|dużymi|dużej|dużym|duża|duże|duży|dużą)\b
# ---------------------------------

# %%
print_registry(regex_container.condition_registry)
# Out:
# Registry: INGREDIENT_CONDITION
